# %% [markdown]
# # **Class_08**

# %%
# import libraries
import seaborn as sns 
import matplotlib.pyplot as plt
sns.set(style='whitegrid')
# load a dataset
kashti=sns.load_dataset("titanic")
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Boxplot 
sns.boxplot(x="alive", y="age", data=kashti)
# Out:
# <Axes: xlabel='alive', ylabel='age'>

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
sns.set(style='whitegrid')
# load a dataset
tip=sns.load_dataset("tips")
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(x='day', y='tip',data=tip)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
sns.set(style='whitegrid')
# load a dataset
tip=sns.load_dataset("tips")
tip
sns.boxplot(x='tip', y='day',data=tip, color='#fc03b1')
# (Jo numaric variables hoty hain on ko hm mostly draw krty hain y-axis py & categorical variables 
# ko mostly x-axis ya hue (numaric ko kabhi bhi hm hue py draw nahi krty hain) py draw krty hain)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np
sns.set(style='whitegrid')
# load a dataset
tip=sns.load_dataset("tips")
tip.describe()
# Note :- Describe function mein only numarical values include hun gi not categorical
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
sns.set_style('whitegrid')
# load a dataset
tip=sns.load_dataset("tips")

# A Boxplot on singal variable
tip=sns.boxplot(y=tip['size'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
sns.set_style('whitegrid')
# load a dataset
tip=sns.load_dataset("tips")

tip=sns.boxplot(x='day', y='tip',hue='smoker', data=tip, palette='Set2', dodge=False)
# dodge ka mtlb hai chakar dena (yani agr koi gari ko side se cross kr k jata hai to ya koi 
# sigtare pita hai chup chup k kain mere parents ko na ptaa chll aye )

# %% [markdown]
# > ### **Assignment**
# #### how to manage individual colors for each hue colors

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
sns.set_style('whitegrid')
# load a dataset
tip=sns.load_dataset("tips")

tip=sns.boxplot(x='day', y='tip',hue='smoker', data=tip)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
sns.set_style('darkgrid')
fig, ax = plt.subplots()

a = pd.DataFrame({'Program': ['A', 'A', 'B', 'B', 'Total', 'Total'],
                  'Scenario': ['X', 'Y', 'X', 'Y', 'X', 'Y'],
                  'Duration': [4, 3, 5, 4, 9, 7]})

g = sns.barplot(data=a, x='Scenario', y='Duration',
                hue='Program', ci=None)
plt.tight_layout()
plt.savefig('3 progs.png')

plt.clf()

b = pd.DataFrame({'Program': ['A', 'A', 'B', 'B', 'C', 'C', 'Total', 'Total'],
                  'Scenario': ['X', 'Y', 'X', 'Y', 'X', 'Y', 'X', 'Y'],
                  'Duration': [4, 3, 5, 4, 3, 2, 12, 9]})

g = sns.barplot(data=b, x='Scenario', y='Duration',
                hue='Program', ci=None)
plt.tight_layout()
plt.savefig('4 progs.png')
# Out:
# C:\Users\Akif\AppData\Local\Temp\ipykernel_10076\1592886441.py:11: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   g = sns.barplot(data=a, x='Scenario', y='Duration',
# C:\Users\Akif\AppData\Local\Temp\ipykernel_10076\1592886441.py:22: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   g = sns.barplot(data=b, x='Scenario', y='Duration',
