# %% [markdown]
# # **Class_04**
# > ## *Body mass index*:
# - #####  (BMI)
# - #####  input weight
# - #####  Height
# - #####  BMI ( Ask your self height & weight)
# - #####  calculate BMI
# - #####  print BMI (my name is..... and my BMI is ....)
# - #####  weight in kg/height in m and its square

# %%
# convert feet into meters
feet=float(input("enter the number :"))
meter= feet/ 3.28084
print("meter:",meter)
# Out:
# meter: 1.7068799453798416

# %%
# convert feet into feet_inches
feet=float(input("enter the number :"))
feet_inches= feet *12
feet_inches
# Out:
# 68.4

# %%
height=input("What is your height ? ")
height=float(height)
height
# Out:
# 1.7

# %%
weight=input("What is your weight ? ")
weight=float(weight)
weight
# Out:
# 65.0

# %%
name=input("What is your name ? ")
name
# Out:
# 'Ali'

# %%
BMI= weight/height**2
BMI
print(" my name is",name," and my BMI is ",BMI,)
# Out:
#  my name is Ali  and my BMI is  22.49134948096886

# %% [markdown]
# ## _**Fundamentals of Visualization**_
# - What is grammer of graphics?
# -  Major parts
# - 1: Mapping   (data) kon sa data ap ny kahan set krna hai
# - 2: Aesthetic (color,size,shape)
# - 3: Geometric (objects: line,bar,point,box,map)
#
# May also contain minor parts-data on specific coordinate

# %% [markdown]
# ### _Python Packages OR Libraries for data science_
# - - Pandas (Data structure & tools 2D dataframes)
# - - Numpy (array & Matrices)
# - - Scipy (optimization & solving different equations)
#
#          scientific computing

# %% [markdown]
# ###  _Python Packages OR Libraries for data science_
# - -   Matplotlib (Plot, Graph, Figures)
# - -   Seaborn    |(heat maps, time series & others plots)
#
#            Data Visualization

# %% [markdown]
# ###  _Python Packages OR Libraries for data science_
# - - Scikit-learn (Machine learning, regression,classification,clustering,analysis and so on)
# - - Statsmodels  (Explor data,estimation of statistical models & perform statistical analysis)
#
#         ML Algorithmic Development

# %% [markdown]
# ## _**Variable Type Matter**_
# - type of visualization depends on variable type
# > Categorical Variable
# - counts(plot type)
# - male vs female
# - true or false
# - 0 vs 1
# - yes or no
# > Continuous Variable
# - Scatter plot
# - Statistical proportions(mean and their comparison)

# %% [markdown]
# ## _**Statistics b/w Groups**_
# - - comparison between group of treatment or variable
#
# ##### **"Mashore Zamana Qual"**
# - - Think before you speak! "Pehly tolo phr bolo"
#
# Now the thing is : Think before you start!
# - Generate a hypothesis
# - Find a story in your data
# - Clean/tidy up data
# - Remove duplicates
# - Handle missing values
# - Find a proper variable to drop duplicate in data
# - - Subset the data if required

# %% [markdown]
# #### _**Categorical Variables**_
#
# - Barplot

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
sns.set_theme(style="ticks",color_codes=True)
df=titanic = sns.load_dataset("titanic")
df
df.shape
# Out:
# (891, 15)

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
sns.set_theme(style="ticks",color_codes=True)

titanic = sns.load_dataset("titanic")
sns.catplot(x="sex", y="survived", hue= "class", kind="bar", data=titanic)
plt.title("Survey Of Sex")
plt.show()

# %% [markdown]
# #### _**Categorical Variables**_
#
# - Countplot

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
sns.set_theme(style="ticks",color_codes=True)
titanic = sns.load_dataset("titanic")
p1=sns.countplot(x='sex', data=titanic,hue= 'class')
p1.set_title("Plot for Counting")
plt.show()

# %% [markdown]
# #### _**Countinuous Variable**_
# - Scatterplot

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
sns.set_theme(style="ticks",color_codes=True)
titanic = sns.load_dataset("titanic")
g=sns.FacetGrid(titanic, row="sex",hue="alone")
g=(g.map(plt.scatter, "age", "fare").add_legend())
plt.show()
