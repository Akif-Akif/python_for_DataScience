# %% [markdown]
# # **Class_06**
#
# > ## _**Line plot**_
# - _**import Libraries**_
#
# seaborn automatically installs these libraries
#   - numpy
#   - scipy
#   - pandas
#   - matplotlib

# %%
# imort libraries
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# ### **_Adding title_**
# ---

# %%
# Load Dataset
phool=sns.load_dataset("iris")
phool
# draw a line plot(line plot 2 numarical variables k drmyan bnta hai)
sns.lineplot(x="sepal_length", y="sepal_width", data=phool)
plt.title("Line Plot on iris dataset") # title
plt.show()

# %% [markdown]
# ### **_Adding limit_**
# ---

# %%
phool=sns.load_dataset("iris")
phool
# draw a line plot(line plot 2 numarical variables k drmyan bnta hai)
sns.lineplot(x="sepal_length", y="sepal_width", data=phool)
plt.title("line plot on iris dataset")
plt.xlim(3)
plt.ylim(0.5)
plt.show()

# %% [markdown]
# ### **_Set styple_**
# - darkgrid
# - whitegrid
# - dark
# - white
# - ticks
# ---

# %%
phool=sns.load_dataset("iris")
phool
# draw a line plot(line plot 2 numarical variables k drmyan bnta hai)
sns.lineplot(x="sepal_length", y="sepal_width", data=phool)
plt.title("Plot_Iris")
sns.set_style("dark")
sns.set_style(style=None, rc=None)
plt.show()

# %% [markdown]
# ### **_Size of figure_**
# ---

# %%
# imort libraries
import seaborn as sns 
import matplotlib.pyplot as plt
# load data set
phool=sns.load_dataset("iris")
# draw a line plot
sns.lineplot(x="sepal_length", y="sepal_width", data=phool)
# add title
plt.title("Plot_on_iris_dataset")
# add figure
plt.figure(figsize=(2,1)) 
plt.show()

# %% [markdown]
# ### **_Barplot_**
# ---

# %%
# imort libraries
import seaborn as sns 
import matplotlib.pyplot as plt
# load data set
phool=sns.load_dataset("iris")
# draw a bar plot
sns.barplot(x="species", y="petal_width", data=phool)
# add title
plt.title("Bar plot on iris dataset")
plt.show()
phool
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
# load data set
kashti=sns.load_dataset("titanic")
# draw a bar plot
sns.barplot(x="sex", y="alone",hue="who", data=kashti)
# add title
plt.title("Bar plot on titanic dataset")
plt.show()
# kashti

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
# load data set
kashti=sns.load_dataset("titanic")
# draw a bar plot| in order shape and we can add colors
sns.barplot(x="sex", y="alone",hue="who", data=kashti,order=["female", "male"],color= "green")
# add title
plt.title("Bar plot on titanic dataset")
plt.show()
# kashti
# Out:
# C:\Users\Akif\AppData\Local\Temp\ipykernel_10068\3564448338.py:6: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:green'` for the same effect.
#
#   sns.barplot(x="sex", y="alone",hue="who", data=kashti,order=["female", "male"],color= "green")

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
# load data set
kashti=sns.load_dataset("titanic")
# remove error bar and palettes color
sns.barplot(x="sex", y="alone",hue="who", data=kashti,order=["female", "male"],color= "green", ci=None,
palette='bright')
# add title
plt.title("Bar plot on titanic dataset")
plt.show()
# Out:
# C:\Users\Akif\AppData\Local\Temp\ipykernel_10068\1194429107.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="sex", y="alone",hue="who", data=kashti,order=["female", "male"],color= "green", ci=None,

# %%
import seaborn as sns 
from numpy import median
import matplotlib.pyplot as plt
# load data set
kashti=sns.load_dataset("titanic")
# estimate (need to numarical values for estimates) and saturation(its mean that intensity of color)
sns.barplot(x="class", y="fare",hue="sex", data=kashti, estimator=median,saturation=0.2)
# add title
plt.title("Bar plot on titanic dataset")
plt.show()

# %%
# horizontal plot
# (make a horizontal plot simpaly numaric parameters adjust on x axis and
#  categorical parameters adjust on y axis)
import seaborn as sns
from numpy import median
import matplotlib.pyplot as plt
# load data set
kashti=sns.load_dataset("titanic")
# estimate (need to numarical values for estimates) and saturation(its mean that intensity of color)
sns.barplot(x="fare", y="class",hue="sex", data=kashti, estimator=median,saturation=3)
# add title
plt.title("Bar plot on titanic dataset")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# load data set
df=sns.load_dataset("titanic")
sns.barplot(x="class",y="fare", data=df,
            linewidth=3, facecolor=(1,0.5,0.4,0.9),
            errcolor=".5", edgecolor="0")
# (black 0 hai white 1 hai 0 se 1 tk ap jitna krty jain gy wo withe hota ajye ga)
# Out:
# C:\Users\Akif\AppData\Local\Temp\ipykernel_10068\2013711690.py:5: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': '.5'}` instead.
#
#   sns.barplot(x="class",y="fare", data=df,
# <Axes: xlabel='class', ylabel='fare'>

# %% [markdown]
# ### **_Boxplot_**
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# load data set
kashti=sns.load_dataset("titanic")
sns.boxplot(x="class",y="fare", data=kashti,)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
import seaborn as sns
tip=sns.load_dataset("tips")
tip
sns.boxplot(x="day",y="tip", data=tip,saturation=5)
# Out:
# <Axes: xlabel='day', ylabel='tip'>
