# %% [markdown]
# # **Class_14**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # _**Pandas_history and Introduction**_
#
# Pandas is a Python library used for working with data sets.
#
# It has functions for analyzing, cleaning, exploring, and manipulating data.
#
# The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis"
#  and was created by Wes McKinney in 2008.
#
# - Development of Pandas started from 2008
# - Pandas become open source in 2009
# - First edition of Python for data analysis is published 2012
# - Pandas becomes a NUMFOCUS sponsored project (NUMFOCUS aik company thi jis ne isy sponsored kya tha)
# - First in-person core developer sprint
#
#
#
# ### **Why Pandas ?**
# Pandas allows us to analyze big data and make conclusions based on statistical theories.
#
# Pandas can clean messy data sets, and make them readable and relevant.
#
# Relevant data is very important in data science.
#
# <span style= "color:green">
#
# - ### Data Manipulation
#
# - ### Data Analysis
# </span>

# %% [markdown]
# ---

# %% [markdown]
# <span style="color:blue">
#
# - ### Data Manipulation
# </span>
#
#  Manipulation of data is the process of manipulation or changing information
# to make it more organized and readable.
#
#
#
# ![image.png](attachment:image.png)
#
# - **Purpose**
#
# - - Consistant Data
#
# - - Project related Data
#
# - - Create more value from Data
#
# - - Remove or ignore Data
#
# **Data Manipulation_Process**
#
# ![image-2.png](attachment:image-2.png)
#
#
# > ## **Note:**
# Most of the time 80-90% of the time data analyst or scientist raw data ---to--> data readable or valueable banany
# mein time spent krty hain, then they can make plot of out it.
# This is the thing if you want to learn data analysis, you have to work with Data Manipulation.

# %% [markdown]
# ## _**After the Data Manipulation the next step  Data Analysis**_

# %% [markdown]
# <span style="color:blue">
#
# - ### Data Analysis
# </span>
#
# #####  After Data Analysis we are move towards  graph and reporting.
# ![image.png](attachment:image.png)
# - ### **Data Analysis**
#
# - Virtual part of Business
# - Learn and adapt (Nokia, Samsung, Appke... eg)
# - Data driven decision making (website)
# - Data driven policy making (Pollution.. eg)
# - How many likes and responses?
# - Should I continue my study?
# - how may I digitalize myself?
# - Should we ban diesel cars? or import gas cars?
#
# > ## **Note:**
#
# We can do all the above things with Data Analysis and Data driven decision making by Pandas in Python.

# %% [markdown]
# ### **Types of Data Analysis**
#
# - **Descriptive Analytics** (What happened?)
# - **Diagnostic Analytics** (Why did it heppen?)
# - **Predictive Analytics** (What is likely to heppen in future based on this data?)
# - **Prescriptive Analytics** (What is the best course of action to take)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # _**Work_with_Pandas**_

# %% [markdown]
# #### **How to install Pandas?**

# %%
pip install pandas

# %% [markdown]
# > ##### **Note:** If you have macbook then you will type "pip3 install pandas"

# %% [markdown]
# #### **Import Libraries**

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# #### **Object Create**

# %%
S = pd.Series([1,3,6,9,np.nan,11]) # add null value 
S
# Out:
# 0     1.0
# 1     3.0
# 2     6.0
# 3     9.0
# 4     NaN
# 5    11.0
# dtype: float64

# %%
dates = pd.date_range("20231110", periods=21)
dates
# Out:
# DatetimeIndex(['2023-11-10', '2023-11-11', '2023-11-12', '2023-11-13',
#                '2023-11-14', '2023-11-15', '2023-11-16', '2023-11-17',
#                '2023-11-18', '2023-11-19', '2023-11-20', '2023-11-21',
#                '2023-11-22', '2023-11-23', '2023-11-24', '2023-11-25',
#                '2023-11-26', '2023-11-27', '2023-11-28', '2023-11-29',
#                '2023-11-30'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# #### Now convert this dates series into dataframe

# %%
df= pd.DataFrame(np.random.randn(21,4), index=dates, columns=list("AKIF"))
df
# Out:
#                    A         K         I         F
# 2023-11-10 -0.282024 -0.651135  1.286345 -1.103345
# 2023-11-11 -1.630063  2.740093 -1.268941 -1.122645
# 2023-11-12  0.186188 -1.502763  0.961745 -1.714370
# 2023-11-13 -0.412842 -0.436491 -0.564786  0.522415
# 2023-11-14 -1.801578  0.504547 -0.712024  1.203770
# 2023-11-15  1.329068 -0.244389 -1.184066  1.251237
# 2023-11-16 -0.126548  0.436716 -0.958667 -1.802065
# 2023-11-17 -0.292636  0.431299  0.577778 -2.278459
# 2023-11-18  0.292665 -1.884532 -0.231314 -0.968557
# 2023-11-19  0.454866  0.704111 -0.069264  0.048543
# 2023-11-20 -0.165743  1.820673 -0.693062  0.671114
# 2023-11-21  1.627823 -0.317268 -0.904550  1.277384
# 2023-11-22  1.066772 -0.353144 -0.568625  0.132520
# 2023-11-23 -0.023832  0.239703  0.721648  0.566266
# 2023-11-24  0.341293  0.347262  1.807249  0.392354
# 2023-11-25 -0.323332  0.299289 -0.841503 -0.610305
# 2023-11-26 -0.084004 -1.341100  0.274448  1.146692
# ...
